# %% [markdown]
# # High pass desgin
# design of a general purpose HP in form as FIR

# %%
import librosa
import os
BASE_FOLDER =  r'../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py

file_path = r'\dataset\min6dB\pump\id_04\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation

# %% [markdown]
# # design

# %%
sr
# Out:
# 16000

# %%
hp = simple_FIR_HP(120,sr)
hp.plot_design()

# %% [markdown]
# # Check on machines

# %%
def check(y, sr):
    hp_filt = hp.apply(y[0])
    fe_psd = feature_extractor_welchPSD(BASE_FOLDER)
    wmf = memory_wave_file()
    wmf.channel = y
    wmf.srate= sr
    fe_psd.create_from_wav(wmf)
    fe_psd.plot()
    wmf.channel = [hp_filt]
    wmf.srate= sr
    fe_psd.create_from_wav(wmf)
    fe_psd.plot()

# %%
file_path = r'\dataset\min6dB\pump\id_04\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\pump\id_00\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\pump\id_06\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\slider\id_06\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\valve\id_06\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\fan\id_06\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\fan\id_00\abnormal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)

# %%
file_path = r'\dataset\min6dB\valve\id_02\normal\00000014.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
check(y, sr)
