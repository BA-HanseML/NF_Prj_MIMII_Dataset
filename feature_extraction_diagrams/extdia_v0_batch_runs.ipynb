# %%
BASE_FOLDER = '../'
# %run -i ..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\utility\extractor_batch.py
print('-'*44)
# %run -i .\extdia_v0
# %run -i .\extdia_v0_allch
print('-'*44)
target_folder=r'\feature_extraction_diagrams\extdia_v0_testout_allch'

# run from RAMdisk
BASE_FOLDER = 'R:\\'
target_folder = r'\out_allch'

extractor_batch(base_folder= BASE_FOLDER, 
 target_folder=target_folder, 
 extdia = extdia_v0_allch, 
 FileFindDict = {'SNR': '6dB',
                 'machine': 'pump', 
                 'ID': ['00']},
n_jobs = 8,
target_class_map = {'abnormal':1, 'normal': 0},
FileCountLimit = None,
datset_folder_from_base = 'dataset')
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load extractor_batch
# --------------------------------------------
# load # extractor diagram V0
# load # extractor diagram V0 all channel to psd
# --------------------------------------------
# 2020-04-29 22:00:17: Target folder will be: R:\out_allch
# 2020-04-29 22:00:17: Extractor diagram is folder will be: <class '__main__.extdia_v0_allch'>
# 2020-04-29 22:00:17: Working on machinepart:pump SNR:6dB ID:00
# 2020-04-29 22:00:17: Files to process: 1149
# 2020-04-29 22:00:17: multithread mode filling the queue
# HBox(children=(FloatProgress(value=0.0, max=1149.0), HTML(value='')))

# %%
# Out:
# '\\dataset\\6dB\\pump\\id_00\\abnormal\\00000002.wav'

# %%
df = pd.read_pickle(r'A:\Dev\NF_Prj_MIMII_Dataset\feature_extraction_diagrams\extdia_v0_testout2\pump6dB00_EDiaV0_pandaDisc.pkl')

# %%
df['MEL_den'][16]
# Out:
# '\\feature_extraction_diagrams\\extdia_v0_testout2\\pump6dB00_EDiaV0_outpMEL_den.pkl'

# %%
# simple check read back
#target_folder=r'\feature_extraction_diagrams\extdia_v0_testout2'
df = pd.read_pickle(os.path.abspath(BASE_FOLDER+target_folder+r'\pump6dB00_EDiaV0_pandaDisc.pkl'))
i = 1
op = 'MEL_den'
fp = os.path.abspath(BASE_FOLDER+df[op][i])
dd = pickle.load( open( fp , "rb" ))
print(dd[i]['para_dict']['wave_filepath'])
fe = feature_extractor_from_dict(dd[i], BASE_FOLDER)
fe.plot()
# Out:
# \dataset\6dB\pump\id_00\abnormal\00000013.wav

# %%
384/60
# Out:
# 6.4
