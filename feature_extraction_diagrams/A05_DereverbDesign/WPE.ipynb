# %%
import librosa
import os
BASE_FOLDER =  r'../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\feature_extractor\WPE_by_TengXiang\wpe.py
file_path = r'\dataset\min6dB\pump\id_00\normal\00000004.wav'
y, sr = librosa.load(os.path.abspath(BASE_FOLDER+file_path), sr=None, mono=False)
t = np.linspace(0,len(y[0])/sr,len(y[0]))
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation

# %%
wpe = WpeMethod(8, 1, 12)
drv_data = wpe.run_offline(y)

# %%
plt.subplot(211)
plt.plot(t,y[0])
plt.title('normal recording')
plt.subplot(212)
plt.plot(t,drv_data[0])
plt.title('dereverb')
# Out:
# Text(0.5, 1.0, 'dereverb')
