# %% [markdown]
# # Test for parallel and joining

# %%
BASE_FOLDER = '../'
# %run -i ..\utility\feature_extractor\JupyterLoad_feature_extractor.py
file_path_list1 = [r'\dataset\6dB\pump\id_00\abnormal\00000004.wav',
                   r'\dataset\6dB\pump\id_00\normal\00000006.wav']

file_path_list2 = [r'\dataset\6dB\valve\id_00\normal\00000014.wav',
                   r'\dataset\6dB\valve\id_00\normal\00000016.wav']
file_target_class1 = [1,
                     0]
file_target_class2 = [0,
                     0]

target_folder = r'/feature_extraction_diagrams/extdia_v1_ess_testout/'
machine = 'pump'
SNR = '6dB'
ID ='00'
# %run -i .\extdia_v1_essential
# single test
ed = []
ed.append(extdia_v1_essential(BASE_FOLDER,0,augment=0, DeviceType=0,fHP = 120))
ed.append(extdia_v1_essential(BASE_FOLDER,1,augment=0, DeviceType=1, fHP = 120))

for tc,f in zip(file_target_class1,file_path_list1):
    #print(f)
    ed[0].execute_diagram(f,tc)
    #print(ed[0].outport_akkulist['MEL_den'][0]['para_dict']['wave_filepath'])  
for tc,f in zip(file_target_class2,file_path_list2):
    ed[1].execute_diagram(f,tc)
    #print(ed[1].outport_akkulist['MEL_den'][0]['para_dict']['wave_filepath'])    


joinlist = outport_akkulist_join(exdia_list=ed)
outport_akkulist_tofile(BASE_FOLDER,target_folder,joinlist,machine,SNR,ID)
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load # extractor diagram V1 essential
#                                             path  abnormal  datafile_idx  \
# 0  \dataset\6dB\pump\id_00\abnormal\00000004.wav       1.0             0
# 1    \dataset\6dB\pump\id_00\normal\00000006.wav       0.0             1
# 2    \dataset\6dB\pump\id_00\normal\00000006.wav      -1.0             2
# 3   \dataset\6dB\valve\id_00\normal\00000014.wav       0.0             3
# 4   \dataset\6dB\valve\id_00\normal\00000014.wav      -1.0             4
# 5   \dataset\6dB\valve\id_00\normal\00000016.wav       0.0             5
# 6   \dataset\6dB\valve\id_00\normal\00000016.wav      -1.0             6
#
#                                              MEL_raw  \
# ...

# %%
np.array([1,2,3]).reshape(1,-1)[0,:]
# Out:
# array([1, 2, 3])

# %% [markdown]
# # Test reloading

# %%
BASE_FOLDER = '../'
# %run -i ..\utility\feature_extractor\JupyterLoad_feature_extractor.py

d_MEL_den = pickle.load( open( r'.\extdia_v1_ess_testout\pump6dB00_EDiaV1HPaug0_outpMEL_den.pkl', "rb" ))
d_MEL_raw = pickle.load( open( r'.\extdia_v1_ess_testout\pump6dB00_EDiaV1HPaug0_outpMEL_raw.pkl', "rb" ))
d_PSD_raw = pickle.load( open( r'.\extdia_v1_ess_testout\pump6dB00_EDiaV1HPaug0_outpPSD_raw.pkl', "rb" ))
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation

# %%
for i in range(len(d_MEL_den)):
    print(d_MEL_den[i]['para_dict']['wave_filepath'])
    print(d_MEL_raw[i]['para_dict']['wave_filepath'])
    print(d_PSD_raw[i]['para_dict']['wave_filepath'])
# Out:
# \dataset\6dB\pump\id_00\abnormal\00000004.wav
# \dataset\6dB\pump\id_00\abnormal\00000004.wav
# \dataset\6dB\pump\id_00\abnormal\00000004.wav
# \dataset\6dB\pump\id_00\normal\00000006.wav
# \dataset\6dB\pump\id_00\normal\00000006.wav
# \dataset\6dB\pump\id_00\normal\00000006.wav
# \dataset\6dB\pump\id_00\normal\00000006.wav
# \dataset\6dB\pump\id_00\normal\00000006.wav
# \dataset\6dB\pump\id_00\normal\00000006.wav
# \dataset\6dB\valve\id_00\normal\00000014.wav
# \dataset\6dB\valve\id_00\normal\00000014.wav
# \dataset\6dB\valve\id_00\normal\00000014.wav
# \dataset\6dB\valve\id_00\normal\00000014.wav
# \dataset\6dB\valve\id_00\normal\00000014.wav
# \dataset\6dB\valve\id_00\normal\00000014.wav
# \dataset\6dB\valve\id_00\normal\00000016.wav
# \dataset\6dB\valve\id_00\normal\00000016.wav
# \dataset\6dB\valve\id_00\normal\00000016.wav
# \dataset\6dB\valve\id_00\normal\00000016.wav
# \dataset\6dB\valve\id_00\normal\00000016.wav
# \dataset\6dB\valve\id_00\normal\00000016.wav

# %%
# compare MELs
plt.figure(figsize=(10,5))
plt.subplot(121)
feature_extractor_from_dict(d_MEL_den[1],BASE_FOLDER).plot()
plt.subplot(122)
feature_extractor_from_dict(d_MEL_den[3],BASE_FOLDER).plot()

# %%
plt.figure(figsize=(10,5))
plt.subplot(121)
feature_extractor_from_dict(d_MEL_raw[0],BASE_FOLDER).plot()
plt.subplot(122)
feature_extractor_from_dict(d_MEL_raw[3],BASE_FOLDER).plot()

# %%
plt.figure(figsize=(10,5))
feature_extractor_from_dict(d_PSD_raw[2],BASE_FOLDER).plot()
feature_extractor_from_dict(d_PSD_raw[1],BASE_FOLDER).plot()
