# %% [markdown]
# # read time wave from memory

# %%
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd

# %%
fe_wav = memory_wave_file()
fe_wav.filepath = r'dataset\6dB\slider\id_02\normal\00000001.wav'
audio_file = os.path.abspath(BASE_FOLDER+fe_wav.filepath)
fe_wav.channel, fe_wav.srate  = librosa.load(audio_file, sr=None, mono=False)

# %%
fe = feature_extractor_welchPSD(BASE_FOLDER)
fe.create_from_wav( fe_wav, channel=0, multichannel='concat')
fe.plot()
plt.legend()

# %%
type(fe_wav) is str
# Out:
# False

# %%
fe = feature_extractor_mel(BASE_FOLDER)
fe.create_from_wav( fe_wav, channel=0, multichannel='concat')
fe.plot()
