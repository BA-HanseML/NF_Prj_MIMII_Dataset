# %% [markdown]
# # PLOT and change hyper parameter

# %%
BASE_FOLDER = '../../'
# %run -i ..\feature_extractor\JupyterLoad_feature_extractor.py
file_path = r'\dataset\6dB\pump\id_02\normal\00000004.wav'
## test:
fe_mel = feature_extractor_mel(BASE_FOLDER,'mel1')
print(fe_mel)
fe_mel.create_from_wav(file_path,0)
print(fe_mel)
fe_mel.plot()
plt.show()
fe_mel.set_hyperparamter(n_mels=12, n_fft=128)
print(fe_mel)
fe_mel.plot()
# Out:
# load feature_extractor_mother
# load feature_extractor_spectra
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 64, 'n_fft': 1024, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 64, 'n_fft': 1024, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\pump\id_02\normal\00000004.wav
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 12, 'n_fft': 128, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\pump\id_02\normal\00000004.wav

# %% [markdown]
# # SAVE and Load from file

# %%
BASE_FOLDER = '../../'
# %run -i ..\feature_extractor\JupyterLoad_feature_extractor.py
file_path = r'\dataset\6dB\pump\id_02\normal\00000004.wav'
## test:
fe_mel = feature_extractor_mel(BASE_FOLDER,'mel1')
fe_mel.set_hyperparamter(n_fft=512)
fe_mel.create_from_wav(file_path,0)
print(fe_mel)
fe_mel.save_to_file('test.pkl')
fe_mel_read = feature_extractor_from_file('test.pkl','../../')
fe_mel_read.plot()
# Out:
# load feature_extractor_mother
# load feature_extractor_spectra
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 64, 'n_fft': 512, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\pump\id_02\normal\00000004.wav

# %%
16000/2
# Out:
# 8000.0

# %% [markdown]
# # 3 outputs

# %%
BASE_FOLDER = '../../'
# %run -i ..\feature_extractor\JupyterLoad_feature_extractor.py
file_path = r'\dataset\6dB\pump\id_02\normal\00000004.wav'
## test:
fe_mel = feature_extractor_mel(BASE_FOLDER,'mel1')
fe_mel.create_from_wav(file_path,0)
fe_mel.feature_data.shape
# Out:
# load feature_extractor_mother
# load feature_extractor_spectra
# (64, 313)

# %%
fp = os.path.abspath(r'A:\dataset\6dB\pump\id_02\normal\00000004.wav')
os.path.exists(fp)
# Out:
# False

# %%
fp
# Out:
# 'A:\\Dev\\NF_Prj_MIMII_Dataset\\utility\\workshop'
