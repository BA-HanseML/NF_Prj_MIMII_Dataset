# %% [markdown]
# # PLOT and change hyper parameter

# %%
BASE_FOLDER = '../../'
# %run -i ..\feature_extractor\JupyterLoad_feature_extractor.py
file_path = r'\dataset\6dB\pump\id_02\normal\00000004.wav'
## test:
fe_mel = feature_extractor_mel(BASE_FOLDER,'mel1')
print(fe_mel)
fe_mel.create_from_wav(file_path,0)
print(fe_mel)
fe_mel.plot()
plt.show()
fe_mel.set_hyperparamter(n_mels=12, n_fft=128)
print(fe_mel)
fe_mel.plot()
# Out:
# load feature_extractor_mother
# load feature_extractor_spectra
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 64, 'n_fft': 1024, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 64, 'n_fft': 1024, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\pump\id_02\normal\00000004.wav
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 12, 'n_fft': 128, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\pump\id_02\normal\00000004.wav

# %% [markdown]
# # SAVE and Load from file

# %%
BASE_FOLDER = '../../'
# %run -i ..\feature_extractor\JupyterLoad_feature_extractor.py
file_path = r'\dataset\6dB\pump\id_02\normal\00000004.wav'
## test:
fe_mel = feature_extractor_mel(BASE_FOLDER,'mel1')
fe_mel.set_hyperparamter(n_fft=512)
fe_mel.create_from_wav(file_path,0)
print(fe_mel)
fe_mel.save_to_file('test.pkl')
fe_mel_read = feature_extractor_from_file('test.pkl','../../')
fe_mel_read.plot()
# Out:
# load feature_extractor_mother
# load feature_extractor_spectra
# <feature_extractor_type.MEL_SPECTRUM>[{'n_mels': 64, 'n_fft': 512, 'power': 2.0, 'hop_length': 512}]wav=A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\pump\id_02\normal\00000004.wav

# %%
16000/2
# Out:
# 8000.0

# %% [markdown]
# # 3 outputs

# %%
BASE_FOLDER = '../../'
# %run -i ..\feature_extractor\JupyterLoad_feature_extractor.py
file_path = r'\dataset\6dB\pump\id_02\normal\00000004.wav'
## test:
fe_mel = feature_extractor_mel(BASE_FOLDER,'mel1')
fe_mel.create_from_wav(file_path,0)
fe_mel.feature_data
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# array([[-16.6068035 , -17.13186008, -16.92814709, ..., -17.99716626,
#         -25.22114232, -19.93149956],
#        [-19.94918584, -20.2206549 , -20.23659218, ..., -20.63698288,
#         -23.10624417, -15.562333  ],
#        [-20.1187777 , -20.86459659, -22.86451677, ..., -24.05917754,
#         -19.8637106 , -20.44767699],
#        ...,
#        [-45.94273068, -50.07762986, -50.52545743, ..., -53.16364876,
#         -52.37651579, -52.34048057],
#        [-43.73392509, -48.43160771, -49.72305116, ..., -49.36074683,
#         -51.08272158, -48.26880596],
#        [-47.00094255, -50.03857496, -50.6429227 , ..., -47.25766857,
#         -50.57092134, -50.32000756]])

# %%
frames = 5
print(fe_mel.feature_data.shape)
n_mels = fe_mel.feature_data.shape[0]
dims = n_mels * frames 
vectorarray_size = len(fe_mel.feature_data[0, :]) - frames + 1
print(dims, vectorarray_size)
vectorarray = np.zeros((vectorarray_size, dims), float)
print(vectorarray.shape)
for t in range(frames):
        vectorarray[:, n_mels * t: n_mels * (t + 1)] = fe_mel.feature_data[:, t: t + vectorarray_size].T

        
plt.imshow(vectorarray[:,0:n_mels].T)
# Out:
# (64, 313)
# 320 309
# (309, 320)

# %%
plt.imshow(vectorarray[:,0:n_mels].T)

# %%
fe_mel.feature_data.flatten().shape
# Out:
# (20032,)

# %%
294*1280
# Out:
# 376320
