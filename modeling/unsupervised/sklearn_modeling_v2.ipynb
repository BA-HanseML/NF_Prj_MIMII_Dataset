# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Structure-cheat-sheet" data-toc-modified-id="Structure-cheat-sheet-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Structure cheat sheet</a></span></li><li><span><a href="#Data-structure" data-toc-modified-id="Data-structure-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data structure</a></span></li><li><span><a href="#get-features" data-toc-modified-id="get-features-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>get features</a></span></li><li><span><a href="#Exploration-of-non-spectral-Features" data-toc-modified-id="Exploration-of-non-spectral-Features-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploration of non-spectral Features</a></span></li><li><span><a href="#Exploring-spectral-features" data-toc-modified-id="Exploring-spectral-features-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploring spectral features</a></span></li><li><span><a href="#Running-the-Auto-Encoder" data-toc-modified-id="Running-the-Auto-Encoder-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Running the Auto-Encoder</a></span></li></ul></div>

# %% [markdown]
# # Basics
#
# ## Structure cheat sheet
#
# 1. func: train data lead (following order)
#     1. read the descriptive dataframe from the feature-pipeline
#     2. extract feature from the feature-objects which are labeled train-dataset from dataframe
#     3. create numpy feature array for the processing pipeline
# 2. preprocessing
#     1. Transformation (any combination of the following)
#         + log-transform
#         + PCA
#         + others
#     2. Scaling (one of the following)
#         + StandardScaler
#         + MinMaxScaler
# 3. Unsupervised Clustering
#     1. Estimate initial hyperparameter
#     2. Create grid over various hyperparameters
#     3. Train all and choose the best according to metric
#
#
# in all steps the cluster-recorder object (possibly dataframe-row) will record all the meta-information like hyper-parameters

# %% [markdown]
# ## Data structure
#
# There are multiple degrees of freedom in the data:
#
# 1. Signal to noise ratio (SNR)
# 2. Machine type
#     1. pump
#     2. fan
#     3. valve (solenoid)
#     4. slider
# 3. Machine ID
#     1. four different machine IDs
#
# The pipeline will be applied to fixed SNR, fixed machine type and fixed ID

# %% [markdown]
# ## get features
#
# Get the descriptive dataframe for the features.
#
# The descriptive dataframe contains all IDs of the pump. We will focus on ID '00' for now since the modeling phase is seperated per SNR, per machine, per ID anyway.

# %% [markdown]
# class:
# + uni\_\<model\>
# attributes:
# + default threshold
# + roc_auc
# methods:
# + fit
# + predict
# + predict_score
# + eval_roc_auc

# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from tqdm import tqdm
import glob
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load tensorflow models
# Load detection_pipe

# %% [markdown]
# The exploration of the Dimensionality Reduction was already done in another notebook. We derived the following rules of thumb:
#
# 1. PCA and ICA deliver almost the same results looking at the relative absolute error
# 2. PCA is usually much faster
# 3. on PSD and the ICA demix matrix, no dimensionality reduction is needed
# 4. for a framed Mel-spectrum a number of components between 32 and 64 is a good measure. The resulting error is about 2-4%
# 5. for a whole Mel-spectrum a number of components between 64 and 128 is advised

# %% [markdown]
# ## Exploration of non-spectral Features

# %%
diagram = 'extdia_v1'
machines = ['pump'
            , 'fan'
            , 'slider'
            , 'valve'
            ]
SNRs = ['6dB', 'min6dB'
        ]
IDs = ['00'
       , '02'
       ,# '04'
       #, '06'
        ]
features = [#('MEL_denbssm', {'function':'frame', 'frames':3})
            #, ('MEL_denbssm', {'function':'frame', 'frames':5})
            #, ('MEL_denbssm', {'function':'frame', 'frames':7})
            #, ('MEL_denbssm', {'function':'flat'})
            ('PSD_denbssm', {'function':'channel'})
            #, ('MEL_bssm', {'function':'frame', 'frames':3})
            #, ('MEL_bssm', {'function':'frame', 'frames':5})
            #, ('MEL_bssm', {'function':'frame', 'frames':7})
            #, ('MEL_bssm', {'function':'flat'})
            , ('PSD_bssm', {'function':'channel'})
            #, ('MEL_raw', {'function':'frame', 'frames':3})
            #, ('MEL_raw', {'function':'frame', 'frames':5})
            #, ('MEL_raw', {'function':'frame', 'frames':7})
            #, ('MEL_raw', {'function':'flat'})
            , ('PSD_raw', {'function':'channel'})
            #, ('MEL_den', {'function':'frame', 'frames':3})
            #, ('MEL_den', {'function':'frame', 'frames':5})
            #, ('MEL_den', {'function':'frame', 'frames':7})
            #, ('MEL_den', {'function':'flat'})
            , ('PSD_den', {'function':'channel'})
            #, ('ICA_demix', {'function':'flat'})
            #, ('ICA_demix', {'function':'maxrange'})
            ]

tasks = [{
        'path_descr':glob.glob(BASE_FOLDER 
                               + '/dataset/{}/{}{}{}_EDiaV1'.format(diagram, machine, SNR, ID) 
                               + "*pandaDisc*.pkl", recursive=True)[0],
        'feat':feature[1], 
        'feat_col':feature[0], 
        'SNR':SNR, 
        'machine':machine, 
        'ID':ID,
        'BASE_FOLDER':BASE_FOLDER}
        for machine in machines
        for SNR in SNRs
        for ID in IDs
        for feature in features
        ]

preprocessing = [
    #(PCA, {'n_components':64}),
    (StandardScaler, {})
]

#modeling = (uni_IsolationForest, {
#    'n_estimators':100
#    ,'max_features':1
#    ,'random_state':42})

# Gaussian Mixture: n_comp: 1, 2, 4, 8, 16, 32
modeling = (uni_GaussianMixture, {'n_components':32})

pipes = [Pipe(preprocessing, modeling) for i in range(len(tasks))]

tasks_failed = []
for pipe, task in tqdm(zip(pipes, tasks), total=len(tasks)):
    try:
        pipe.run_pipe(task)
    except:
        tasks_failed.append(task)
        print('Task failed')
# Out:
# 0%|          | 0/64 [00:00<?, ?it/s]../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5097070761406426
#   2%|▏         | 1/64 [00:17<18:22, 17.50s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8925130813242701
#   3%|▎         | 2/64 [00:34<17:58, 17.39s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.876473177172478
#   5%|▍         | 3/64 [01:15<24:51, 24.45s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8832705755782678
#   6%|▋         | 4/64 [01:44<25:55, 25.92s/it]pipe saved to pickle
# Task failed
# Task failed
# Task failed
# Task failed
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4181133551762922
#  14%|█▍        | 9/64 [02:03<17:40, 19.29s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6590053303340017
#  16%|█▌        | 10/64 [02:25<17:58, 19.97s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7279084551811824
#  17%|█▋        | 11/64 [02:55<20:17, 22.96s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6311800088023864
#  19%|█▉        | 12/64 [03:30<23:00, 26.55s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7156886616346075
#  20%|██        | 13/64 [03:42<18:52, 22.21s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6500284067851636
#  22%|██▏       | 14/64 [03:54<15:53, 19.08s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7596785975164353
#  23%|██▎       | 15/64 [04:06<13:49, 16.94s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8309390471552633
#  25%|██▌       | 16/64 [04:18<12:29, 15.61s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.637818519882402
#  27%|██▋       | 17/64 [04:30<11:22, 14.53s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8075026109424144
#  28%|██▊       | 18/64 [04:43<10:40, 13.93s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6818453476930135
#  30%|██▉       | 19/64 [04:55<10:07, 13.49s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6182892743089303
#  31%|███▏      | 20/64 [05:11<10:21, 14.12s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8883543734142348
#  33%|███▎      | 21/64 [05:26<10:22, 14.47s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9968886026644734
#  34%|███▍      | 22/64 [05:42<10:31, 15.04s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9987430265128296
#  36%|███▌      | 23/64 [06:00<10:51, 15.88s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9183665551943265
#  38%|███▊      | 24/64 [06:15<10:17, 15.45s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.525007696997869
#  39%|███▉      | 25/64 [06:28<09:36, 14.78s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5361094845124329
#  41%|████      | 26/64 [06:40<08:52, 14.01s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.53464252727152
#  42%|████▏     | 27/64 [06:53<08:20, 13.52s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5073860995236916
#  44%|████▍     | 28/64 [07:05<07:58, 13.28s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6547978367641467
#  45%|████▌     | 29/64 [07:17<07:30, 12.87s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7038430800505893
#  47%|████▋     | 30/64 [07:30<07:13, 12.75s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7231011553293349
#  48%|████▊     | 31/64 [07:41<06:49, 12.41s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5889851878864999
#  50%|█████     | 32/64 [07:53<06:34, 12.34s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9732672642343138
#  52%|█████▏    | 33/64 [08:05<06:19, 12.24s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9908786769347304
#  53%|█████▎    | 34/64 [08:17<06:04, 12.15s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9998500820603459
#  55%|█████▍    | 35/64 [08:30<05:56, 12.28s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9993214240626184
#  56%|█████▋    | 36/64 [08:43<05:46, 12.39s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9698270420401465
#  58%|█████▊    | 37/64 [08:52<05:12, 11.57s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9810770245058844
#  59%|█████▉    | 38/64 [09:02<04:43, 10.92s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9792113790346337
#  61%|██████    | 39/64 [09:11<04:21, 10.45s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9952306807501858
#  62%|██████▎   | 40/64 [09:21<04:07, 10.33s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9179002019946977
#  64%|██████▍   | 41/64 [09:33<04:10, 10.91s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9652900517611414
#  66%|██████▌   | 42/64 [09:46<04:09, 11.32s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9934272819088499
#  67%|██████▋   | 43/64 [09:58<04:02, 11.55s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9790667213735639
#  69%|██████▉   | 44/64 [10:10<03:55, 11.79s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7770343250711892
#  70%|███████   | 45/64 [10:20<03:30, 11.09s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8278556299008262
#  72%|███████▏  | 46/64 [10:29<03:11, 10.62s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8566118194952939
#  73%|███████▎  | 47/64 [10:39<02:55, 10.30s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HP_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8512954312727068
#  78%|███████▊  | 50/64 [10:48<01:39,  7.11s/it]pipe saved to pickle
# ../..//dataset/extdia_v1\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
#  86%|████████▌ | 55/64 [10:49<00:31,  3.51s/it]../..//dataset/extdia_v1\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
#  89%|████████▉ | 57/64 [10:49<00:17,  2.47s/it]
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
#  95%|█████████▌| 61/64 [10:49<00:03,  1.24s/it]
# ../..//dataset/extdia_v1\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# 100%|██████████| 64/64 [10:49<00:00, 10.15s/it]
# ...loading data
# Task failed
# ../..//dataset/extdia_v1\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed

# %% [markdown]
# ## Exploring spectral features

# %%
def run_GMM(i):
    diagram = 'extdia_v1'
    machines = [#'pump'
                #, 'fan'
                #, 'slider'
                'valve'
                ]
    SNRs = ['6dB', 'min6dB'
            ]
    IDs = ['00'
        , '02'
        ,# '04'
        #, '06'
            ]
    features = [('MEL_denbssm', {'function':'frame', 'frames':3})
                , ('MEL_denbssm', {'function':'frame', 'frames':5})
                , ('MEL_denbssm', {'function':'frame', 'frames':7})
                #, ('MEL_denbssm', {'function':'flat'})
                #, ('PSD_denbssm', {'function':'channel'})
                , ('MEL_bssm', {'function':'frame', 'frames':3})
                , ('MEL_bssm', {'function':'frame', 'frames':5})
                , ('MEL_bssm', {'function':'frame', 'frames':7})
                #, ('MEL_bssm', {'function':'flat'})
                #, ('PSD_bssm', {'function':'channel'})
                , ('MEL_raw', {'function':'frame', 'frames':3})
                , ('MEL_raw', {'function':'frame', 'frames':5})
                , ('MEL_raw', {'function':'frame', 'frames':7})
                #, ('MEL_raw', {'function':'flat'})
                #, ('PSD_raw', {'function':'channel'})
                , ('MEL_den', {'function':'frame', 'frames':3})
                , ('MEL_den', {'function':'frame', 'frames':5})
                , ('MEL_den', {'function':'frame', 'frames':7})
                #, ('MEL_den', {'function':'flat'})
                #, ('PSD_den', {'function':'channel'})
                #, ('ICA_demix', {'function':'flat'})
                #, ('ICA_demix', {'function':'maxrange'})
                ]

    tasks = [{
            'path_descr':glob.glob(BASE_FOLDER 
                               + '/dataset/extdia_v1*/{}{}{}_EDiaV1'.format(machine, SNR, ID) 
                               + "*pandaDisc*.pkl", recursive=True)[0],
            'feat':feature[1], 
            'feat_col':feature[0], 
            'SNR':SNR, 
            'machine':machine, 
            'ID':ID,
            'BASE_FOLDER':BASE_FOLDER}
            for machine in machines
            for SNR in SNRs
            for ID in IDs
            for feature in features
            ]

    preprocessing = [
        (PCA, {'n_components':64}),
        (StandardScaler, {})
    ]

    # Gaussian Mixture: n_comp: 1, 2, 4, 8, 16, 32
    modeling = (uni_GaussianMixture, {'n_components':i})

    pipes = [Pipe(preprocessing, modeling) for i in range(len(tasks))]

    # # create the threads
    # n_jobs = 2
    # worker_list = []
    # queue = Queue()
    # for worker in range(n_jobs):
    #     worker = PipeThread(queue)
    #     worker.daemon = True
    #     worker.start()
    #     worker_list.append(worker)

    tasks_failed = []
    for pipe, task in tqdm(zip(pipes, tasks), total=len(tasks)):
        try:
            pipe.run_pipe(task)
        except:
            tasks_failed.append(task)
            print('Task failed')

# %%
for i in [1, 2, 4, 8, 16, 32]:
    run_GMM(i)
# Out:
# _pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6910883069462535
#  71%|███████   | 34/48 [1:04:12<32:13, 138.08s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6283972934642651
#  73%|███████▎  | 35/48 [1:06:03<28:06, 129.72s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7893140445889216
#  81%|████████▏ | 39/48 [1:08:19<13:49, 92.13s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
#  88%|████████▊ | 42/48 [1:08:19<06:27, 64.50s/it]Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
#  88%|████████▊ | 42/48 [1:08:38<06:27, 64.50s/it]model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7067023298111751
#  90%|████████▉ | 43/48 [1:10:20<06:46, 81.38s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.63268997235052
#  92%|█████████▏| 44/48 [1:11:38<05:22, 80.55s/it]
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7708380099228875
# pipe saved to pickle
# 100%|██████████| 48/48 [1:12:53<00:00, 91.12s/it]
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
#   0%|          | 0/48 [00:00<?, ?it/s]../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9566450656669214
#   2%|▏         | 1/48 [05:02<3:57:12, 302.82s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9546245863937868
#   4%|▍         | 2/48 [14:01<4:46:28, 373.67s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.963482000846734
#   6%|▋         | 3/48 [21:48<5:01:15, 401.68s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.907007525580974
#   8%|▊         | 4/48 [28:01<4:48:16, 393.11s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9212140666076452
#  10%|█         | 5/48 [32:37<4:16:24, 357.79s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9178798400406802
#  12%|█▎        | 6/48 [39:34<4:22:57, 375.65s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7439141277822153
#  15%|█▍        | 7/48 [44:10<3:56:20, 345.86s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8439518867730917
#  17%|█▋        | 8/48 [50:34<3:58:11, 357.30s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9111001003342357
#  19%|█▉        | 9/48 [55:51<3:44:21, 345.17s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9147711967030889
#  21%|██        | 10/48 [1:02:17<3:46:18, 357.33s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.947609111345103
#  23%|██▎       | 11/48 [1:08:38<3:44:41, 364.37s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9403355740863845
#  29%|██▉       | 14/48 [1:20:13<3:03:54, 324.54s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
#  35%|███▌      | 17/48 [1:20:13<1:57:23, 227.19s/it]Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
#  35%|███▌      | 17/48 [1:20:23<1:57:23, 227.19s/it]data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.870917278248203
#  40%|███▉      | 19/48 [1:22:50<1:28:12, 182.50s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.850476778247912
#  42%|████▏     | 20/48 [1:27:06<1:35:28, 204.59s/it]
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8535819389772483
#  50%|█████     | 24/48 [1:29:36<52:43, 131.81s/it]
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8206149167243633
#  52%|█████▏    | 25/48 [1:34:45<1:10:49, 184.78s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8049539769924074
#  54%|█████▍    | 26/48 [1:39:25<1:18:19, 213.62s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7964816253676108
#  56%|█████▋    | 27/48 [1:42:37<1:12:25, 206.92s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7364531406542146
#  58%|█████▊    | 28/48 [1:45:37<1:06:15, 198.79s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7874500547549717
#  60%|██████    | 29/48 [1:52:46<1:24:54, 268.13s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8064485054066827
#  62%|██████▎   | 30/48 [2:00:18<1:36:57, 323.20s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6013096289854023
#  65%|██████▍   | 31/48 [2:03:42<1:21:23, 287.29s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7166154236225548
#  67%|██████▋   | 32/48 [2:09:43<1:22:30, 309.40s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7237107612348779
#  69%|██████▉   | 33/48 [2:19:16<1:37:07, 388.50s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6152028948433892
#  71%|███████   | 34/48 [2:24:15<1:24:24, 361.75s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7146583876084057
#  73%|███████▎  | 35/48 [2:30:38<1:19:44, 368.01s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7903684538812938
#  81%|████████▏ | 39/48 [2:36:59<39:03, 260.44s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
#  88%|████████▊ | 42/48 [2:36:59<18:13, 182.32s/it]../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
#  88%|████████▊ | 42/48 [2:37:12<18:13, 182.32s/it]data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7157597389226056
#  90%|████████▉ | 43/48 [2:39:19<14:07, 169.59s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.781000575012597
#  92%|█████████▏| 44/48 [2:41:46<10:50, 162.67s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6728738994872919
# 100%|██████████| 48/48 [2:44:50<00:00, 206.06s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
# ../..//dataset\extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# Task failed
#
#   0%|          | 0/48 [00:00<?, ?it/s]../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9636068354970089
#   2%|▏         | 1/48 [17:31<13:43:30, 1051.29s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9548294097653811
#   4%|▍         | 2/48 [31:58<12:43:37, 996.04s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9753523003563794
#   6%|▋         | 3/48 [45:28<11:45:08, 940.18s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.909788422365115
#   8%|▊         | 4/48 [1:02:10<11:43:06, 958.77s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9046273746727903
#  10%|█         | 5/48 [1:13:56<10:32:44, 882.90s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9492191618236064
#  12%|█▎        | 6/48 [1:44:11<13:33:55, 1162.75s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8180865026473558
#  15%|█▍        | 7/48 [1:54:22<11:21:24, 997.19s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8658694312070065
#  17%|█▋        | 8/48 [2:04:11<9:43:01, 874.55s/it]pipe saved to pickle
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
#  19%|█▉        | 9/48 [2:09:14<7:36:58, 703.04s/it]Task failed
# ../..//dataset\extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data

# %% [markdown]
# ## Running the Auto-Encoder

# %%
diagram = 'extdia_v1'
machines = ['pump'
            , 'fan'
            , 'slider'
            , 'valve'
            ]
SNRs = ['6dB', 'min6dB'
        ]
IDs = ['00'
       , '02'
       ,# '04'
       #, '06'
        ]
features = [('MEL_denbssm', {'function':'frame', 'frames':3})
            , ('MEL_denbssm', {'function':'frame', 'frames':5})
            , ('MEL_denbssm', {'function':'frame', 'frames':7})
            , ('MEL_denbssm', {'function':'flat'})
            #('PSD_denbssm', {'function':'channel'})
            , ('MEL_bssm', {'function':'frame', 'frames':3})
            , ('MEL_bssm', {'function':'frame', 'frames':5})
            , ('MEL_bssm', {'function':'frame', 'frames':7})
            , ('MEL_bssm', {'function':'flat'})
            #, ('PSD_bssm', {'function':'channel'})
            , ('MEL_raw', {'function':'frame', 'frames':3})
            , ('MEL_raw', {'function':'frame', 'frames':5})
            , ('MEL_raw', {'function':'frame', 'frames':7})
            , ('MEL_raw', {'function':'flat'})
            #, ('PSD_raw', {'function':'channel'})
            , ('MEL_den', {'function':'frame', 'frames':3})
            , ('MEL_den', {'function':'frame', 'frames':5})
            , ('MEL_den', {'function':'frame', 'frames':7})
            , ('MEL_den', {'function':'flat'})
            #, ('PSD_den', {'function':'channel'})
            #, ('ICA_demix', {'function':'flat'})
            #, ('ICA_demix', {'function':'maxrange'})
            ]

tasks = [{
        'path_descr':glob.glob(BASE_FOLDER 
                               + '/dataset/{}/{}{}{}_EDiaV1'.format(diagram, machine, SNR, ID) 
                               + "*pandaDisc*.pkl", recursive=True)[0],
        'feat':feature[1], 
        'feat_col':feature[0], 
        'SNR':SNR, 
        'machine':machine, 
        'ID':ID,
        'BASE_FOLDER':BASE_FOLDER}
        for machine in machines
        for SNR in SNRs
        for ID in IDs
        for feature in features
        ]

preprocessing = [
    (PCA, {'n_components':64}),
    (StandardScaler, {})
]

modeling = (uni_AutoEncoder, {'epochs':50})

# modeling = (uni_EllipticEnvelope, {})

pipes = [Pipe(preprocessing, modeling) for i in range(len(tasks))]

# create the threads
n_jobs = 1
worker_list = []
queue = Queue()
for worker in range(n_jobs):
    worker = PipeThread(queue)
    worker.daemon = True
    worker.start()
    worker_list.append(worker)

# %%
# fill the Queue
task_status = []
for pipe, task in (zip(pipes[5:], tasks[5:])):
    queue.put((pipe, task))
# Out:
# ../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# Epoch 1/50
# 1042/1042 [==============================] - 9s 9ms/step - loss: 0.9007
# Epoch 2/50
# 1042/1042 [==============================] - 6s 6ms/step - loss: 0.8526
# Epoch 3/50
# 1042/1042 [==============================] - 7s 6ms/step - loss: 0.8278
# Epoch 4/50
# 1042/1042 [==============================] - 7s 7ms/step - loss: 0.8146
# Epoch 5/50
# 1042/1042 [==============================] - 7s 7ms/step - loss: 0.8049
# Epoch 6/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7989
# Epoch 7/50
# 1042/1042 [==============================] - 9s 9ms/step - loss: 0.7933
# Epoch 8/50
# 1042/1042 [==============================] - 10s 9ms/step - loss: 0.7889
# Epoch 9/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7863
# Epoch 10/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7823
# Epoch 11/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7801
# Epoch 12/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7780
# Epoch 13/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7758
# Epoch 14/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7735
# Epoch 15/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7718
# Epoch 16/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7696
# Epoch 17/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7673
# Epoch 18/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7654
# Epoch 19/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7637
# Epoch 20/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7625
# Epoch 21/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7618
# Epoch 22/50
# 1042/1042 [==============================] - 8s 7ms/step - loss: 0.7609
# Epoch 23/50
#  608/1042 [================>.............] - ETA: 3s - loss: 0.7589
