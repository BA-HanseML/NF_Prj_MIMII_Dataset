# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from sklearn.preprocessing import PolynomialFeatures

# %run -i miniutil_singel_pipe_eval_helper.py

df_summery = pd.DataFrame()
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load tensorflow models
# Load detection_pipe

# %% [markdown]
# # Feature list
#
# * PSD_raw
# * PSD_den
# * PSD_bssm
# * PSD_denbssm
# * ICA_demix
# * MEL_raw
# * MEL_den
# * MEL_bssm
# * MEL_denbssm

# %% [markdown]
# # Low noise ID00

# %%
## Meta
machines = ['fan']
SNRs = ['6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
for psd in ['PSD_raw','PSD_bssm','PSD_den']:
    df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ psd],
                        feat = {'function':'flat'})

    preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
    ]

    #modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
    modeling = (uni_svm, {'C': 0.1, 'degree':3,'kernel':'rbf'})

    pipe = Pipe(preprocessing, modeling, True)
    pipe.run_pipe(tasks[0])

    name_of_test = pipe.model.name + 'n' +'_' + npart

    pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
    print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9912065260295602
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.3582756310029037
# pipe saved to pickle
# SVMn_fan006dBPSD_raw
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9868975044954168
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.723022777076831
# pipe saved to pickle
# SVMn_fan006dBPSD_bssm
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9686472084557696
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7950576218389487
# pipe saved to pickle
# SVMn_fan006dBPSD_den

# %% [markdown]
# # High noise ID00

# %%
## Meta
machines = ['fan']
SNRs = ['min6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSDs

# %%
for psd in ['PSD_raw','PSD_bssm','PSD_den']:
    df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ psd],
                        feat = {'function':'flat'})

    preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
    ]

    #modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
    modeling = (uni_svm, {'C': 0.1, 'degree':3,'kernel':'rbf'})

    pipe = Pipe(preprocessing, modeling, True)
    pipe.run_pipe(tasks[0])

    name_of_test = pipe.model.name + 'n' +'_' + npart

    pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
    print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9662185869040831
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.43963440769337575
# pipe saved to pickle
# SVMn_fan00min6dBPSD_raw
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9473433182755143
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5104166037826972
# pipe saved to pickle
# SVMn_fan00min6dBPSD_bssm
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9185932086312003
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4498548134911772
# pipe saved to pickle
# SVMn_fan00min6dBPSD_den

# %% [markdown]
# # High noise ID02

# %%
## Meta
machines = ['fan']
SNRs = ['min6dB']
IDs = ['02']
feat_discfile = '/dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSDs

# %%
for psd in ['PSD_raw','PSD_bssm','PSD_den']:
    df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ psd],
                        feat = {'function':'flat'})

    preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
    ]

    #modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
    modeling = (uni_svm, {'C': 0.1, 'degree':3,'kernel':'rbf'})

    pipe = Pipe(preprocessing, modeling, True)
    pipe.run_pipe(tasks[0])

    name_of_test = pipe.model.name + 'n' +'_' + npart

    pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
    print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9886458673598224
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4768274609911468
# pipe saved to pickle
# SVMn_fan02min6dBPSD_raw
# ../..//dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9906706606525209
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6171972594874342
# pipe saved to pickle
# SVMn_fan02min6dBPSD_bssm
# ../..//dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9417999346691408
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5049697007316827
# pipe saved to pickle
# SVMn_fan02min6dBPSD_den

# %% [markdown]
# # Summery

# %%
df_summery.to_pickle('S01_summerys/S01_SVM_fan')
