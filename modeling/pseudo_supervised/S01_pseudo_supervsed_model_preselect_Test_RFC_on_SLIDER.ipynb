# %% [markdown]
# # Model Preselect test logeristic regression

# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from sklearn.preprocessing import PolynomialFeatures

# %run -i miniutil_singel_pipe_eval_helper.py

df_summery = pd.DataFrame()
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load detection_pipe

# %% [markdown]
# # Feature list
#
# * PSD_raw
# * PSD_den
# * PSD_bssm
# * PSD_denbssm
# * ICA_demix
# * MEL_raw
# * MEL_den
# * MEL_bssm
# * MEL_denbssm

# %% [markdown]
# # Low noise ID00

# %%
## Meta
machines = ['slider']
SNRs = ['6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/slider6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_bssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slider6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9821932994571394
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9582596894331523
# pipe saved to pickle
# RFCn_slider006dBPSD_bssm

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slider6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9947232830450701
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9897976896856457
# pipe saved to pickle
# RFCn_slider006dBPSD_raw

# %% [markdown]
# ## PSD_den

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_den'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slider6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9909348961621006
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.999510794091655
# pipe saved to pickle
# RFCn_slider006dBPSD_den

# %% [markdown]
# # High noise ID00

# %%
## Meta
machines = ['slider']
SNRs = ['min6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.981193188991289
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9567999621259942
# pipe saved to pickle
# RFCn_slider00min6dBPSD_raw

# %% [markdown]
# ## MEL_denbssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'MEL_denbssm'],
                        feat = {'function':'frame', 'frames':5})

preprocessing = [
    (PCA, {'n_components':64}),
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'pca' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9289873842345517
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6396053814488132
# pipe saved to pickle
# RFCpca_slider00min6dBMEL_denbssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'MEL_raw'],
                        feat = {'function':'frame', 'frames':5})

preprocessing = [
    (PCA, {'n_components':64}),
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'pca' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.969318833236996
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7646630773766363
# pipe saved to pickle
# RFCpca_slider00min6dBMEL_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'MEL_den'],
                        feat = {'function':'frame', 'frames':5})

preprocessing = [
    (PCA, {'n_components':64}),
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'pca' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9344394571757565
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8349644186737303
# pipe saved to pickle
# RFCpca_slider00min6dBMEL_den

# %% [markdown]
# # High noise ID02

# %%
## Meta
machines = ['slider']
SNRs = ['min6dB']
IDs = ['02']
feat_discfile = '/dataset/extdia_v1/slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9833066033251194
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8061201587902762
# pipe saved to pickle
# RFCn_slider02min6dBPSD_raw

# %% [markdown]
# ## PSD_bssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9619950717034418
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6335619801091332
# pipe saved to pickle
# RFCn_slider02min6dBPSD_bssm

# %% [markdown]
# ## MEL_raw framed

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'MEL_raw'],
                        feat = {'function':'frame','frames':5})

preprocessing = [
    (FastICA, {'n_components': 128}),
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'pca' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9609122032086655
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6596855318603576
# pipe saved to pickle
# RFCpca_slider02min6dBMEL_raw

# %% [markdown]
# # High noise ID06

# %%
## Meta
machines = ['slider']
SNRs = ['min6dB']
IDs = ['06']
feat_discfile = '/dataset/extdia_v1/slidermin6dB06_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.981850776417119
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6159575811134957
# pipe saved to pickle
# RFCn_slider06min6dBPSD_raw

# %% [markdown]
# ## PSD_bssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})
pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/slidermin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9618331018810754
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6183562681479611
# pipe saved to pickle
# RFCn_slider06min6dBPSD_bssm

# %% [markdown]
# # Summery
#
# for the slider in RFC the PSD seems better and the raw form

# %%
df_summery[[c for c in df_summery.columns if 'min6dB' in c]].loc['test  ROC-AUC']
# Out:
# RFCn_slider00min6dBPSD_raw          0.956800
# RFCpca_slider00min6dBMEL_denbssm    0.639605
# RFCpca_slider00min6dBMEL_raw        0.764663
# RFCpca_slider00min6dBMEL_den        0.834964
# RFCn_slider02min6dBPSD_raw          0.806120
# RFCn_slider02min6dBPSD_bssm         0.633562
# RFCpca_slider02min6dBMEL_raw        0.659686
# RFCn_slider06min6dBPSD_raw          0.615958
# RFCn_slider06min6dBPSD_bssm         0.618356
# Name: test  ROC-AUC, dtype: float64

# %%
df_summery.to_pickle('S01_summerys/S01_RFC_slider')
