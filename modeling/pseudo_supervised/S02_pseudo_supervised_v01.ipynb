# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Structure-cheat-sheet" data-toc-modified-id="Structure-cheat-sheet-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Structure cheat sheet</a></span></li><li><span><a href="#Data-structure" data-toc-modified-id="Data-structure-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data structure</a></span></li><li><span><a href="#get-features" data-toc-modified-id="get-features-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>get features</a></span></li><li><span><a href="#Exploration-of-the-Features" data-toc-modified-id="Exploration-of-the-Features-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploration of the Features</a></span></li><li><span><a href="#Exploring-spectral-features" data-toc-modified-id="Exploring-spectral-features-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploring spectral features</a></span></li></ul></div>

# %% [markdown]
# # Basics
#
# ## Structure cheat sheet
#
# 1. func: train data lead (following order)
#     1. read the descriptive dataframe from the feature-pipeline
#     2. extract feature from the feature-objects which are labeled train-dataset from dataframe
#     3. create numpy feature array for the processing pipeline
# 2. preprocessing
#     1. Transformation (any combination of the following)
#         + log-transform
#         + PCA
#         + others
#     2. Scaling (one of the following)
#         + StandardScaler
#         + MinMaxScaler
# 3. Unsupervised Clustering
#     1. Estimate initial hyperparameter
#     2. Create grid over various hyperparameters
#     3. Train all and choose the best according to metric
#
#
# in all steps the cluster-recorder object (possibly dataframe-row) will record all the meta-information like hyper-parameters

# %% [markdown]
# ## Data structure
#
# There are multiple degrees of freedom in the data:
#
# 1. Signal to noise ratio (SNR)
# 2. Machine type
#     1. pump
#     2. fan
#     3. valve (solenoid)
#     4. slider
# 3. Machine ID
#     1. four different machine IDs
#
# The pipeline will be applied to fixed SNR, fixed machine type and fixed ID

# %% [markdown]
# ## get features
#
# Get the descriptive dataframe for the features.
#
# The descriptive dataframe contains all IDs of the pump. We will focus on ID '00' for now since the modeling phase is seperated per SNR, per machine, per ID anyway.

# %% [markdown]
# class:
# + uni\_\<model\>
# attributes:
# + default threshold
# + roc_auc
# methods:
# + fit
# + predict
# + predict_score
# + eval_roc_auc

# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from tqdm.auto import tqdm
import glob
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load tensorflow models
# Load detection_pipe

# %% [markdown]
# ## RFC

# %%
diagram = 'extdia_v1'
machines = ['slider',
            'pump',
            'fan',
            'valve',
            ]
SNRs = ['6dB', 'min6dB']

IDs = ['00'
       ,'02'
       , '04'
       ,'06'
        ]
features = [#('MEL_denbssm', {'function':'frame', 'frames':3})
            #, ('MEL_denbssm', {'function':'frame', 'frames':5})
            #, ('MEL_denbssm', {'function':'frame', 'frames':7})
            #, ('MEL_denbssm', {'function':'flat'})
            #('PSD_denbssm', {'function':'flat'})
            #, ('MEL_bssm', {'function':'frame', 'frames':3})
            #, ('MEL_bssm', {'function':'frame', 'frames':5})
            #, ('MEL_bssm', {'function':'frame', 'frames':7})
            #, ('MEL_bssm', {'function':'flat'})
             #('PSD_bssm', {'function':'flat'})
            #, ('MEL_raw', {'function':'frame', 'frames':3})
            #, ('MEL_raw', {'function':'frame', 'frames':5})
            #, ('MEL_raw', {'function':'frame', 'frames':7})
            #, ('MEL_raw', {'function':'flat'})
             ('PSD_raw', {'function':'flat'})
            #, ('MEL_den', {'function':'frame', 'frames':3})
            #, ('MEL_den', {'function':'frame', 'frames':5})
            #, ('MEL_den', {'function':'frame', 'frames':7})
            #, ('MEL_den', {'function':'flat'})
            #, ('PSD_den', {'function':'flat'})
            #, ('ICA_demix', {'function':'flat'})
            #, ('ICA_demix', {'function':'maxrange'})
            ]

tasks = []
for machine in machines:
    for SNR in SNRs:
        for ID in IDs:
            for feature in features:
                print(machine,SNR,ID,feature)
                if machine == 'valve':
                    diagram_patch = 'extdia_v1_sporafic'
                else:
                    diagram_patch = diagram
                path = glob.glob(BASE_FOLDER \
                    + '/dataset/{}/{}{}{}_EDiaV1*aug0'.format(diagram_patch, machine, SNR, ID) 
                    + "*pandaDisc*.pkl", recursive=True)[0]
                d = {
                'path_descr': path,
                'feat':feature[1], 
                'feat_col':feature[0], 
                'SNR':SNR, 
                'machine':machine, 
                'ID':ID,
                'BASE_FOLDER':BASE_FOLDER}
                tasks.append(d)


preprocessing = [
    #(PCA, {'n_components':64}),
    (StandardScaler, {})
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})

# modeling = (uni_EllipticEnvelope, {})

pipes = [Pipe(preprocessing, modeling, pseudo_sup=True) for i in range(len(tasks))]

tasks_failed = []
for pipe, task in tqdm(zip(pipes, tasks), total=len(tasks)):
    try:
        pipe.run_pipe(task)
    except:
        tasks_failed.append(task)
        print('Task failed')
# Out:
# slider 6dB 00 ('PSD_raw', {'function': 'flat'})
# slider 6dB 02 ('PSD_raw', {'function': 'flat'})
# slider 6dB 04 ('PSD_raw', {'function': 'flat'})
# slider 6dB 06 ('PSD_raw', {'function': 'flat'})
# slider min6dB 00 ('PSD_raw', {'function': 'flat'})
# slider min6dB 02 ('PSD_raw', {'function': 'flat'})
# slider min6dB 04 ('PSD_raw', {'function': 'flat'})
# slider min6dB 06 ('PSD_raw', {'function': 'flat'})
# pump 6dB 00 ('PSD_raw', {'function': 'flat'})
# pump 6dB 02 ('PSD_raw', {'function': 'flat'})
# pump 6dB 04 ('PSD_raw', {'function': 'flat'})
# pump 6dB 06 ('PSD_raw', {'function': 'flat'})
# pump min6dB 00 ('PSD_raw', {'function': 'flat'})
# pump min6dB 02 ('PSD_raw', {'function': 'flat'})
# pump min6dB 04 ('PSD_raw', {'function': 'flat'})
# pump min6dB 06 ('PSD_raw', {'function': 'flat'})
# fan 6dB 00 ('PSD_raw', {'function': 'flat'})
# fan 6dB 02 ('PSD_raw', {'function': 'flat'})
# fan 6dB 04 ('PSD_raw', {'function': 'flat'})
# fan 6dB 06 ('PSD_raw', {'function': 'flat'})
# fan min6dB 00 ('PSD_raw', {'function': 'flat'})
# fan min6dB 02 ('PSD_raw', {'function': 'flat'})
# fan min6dB 04 ('PSD_raw', {'function': 'flat'})
# fan min6dB 06 ('PSD_raw', {'function': 'flat'})
# valve 6dB 00 ('PSD_raw', {'function': 'flat'})
# valve 6dB 02 ('PSD_raw', {'function': 'flat'})
# valve 6dB 04 ('PSD_raw', {'function': 'flat'})
# valve 6dB 06 ('PSD_raw', {'function': 'flat'})
# valve min6dB 00 ('PSD_raw', {'function': 'flat'})
# valve min6dB 02 ('PSD_raw', {'function': 'flat'})
# valve min6dB 04 ('PSD_raw', {'function': 'flat'})
# valve min6dB 06 ('PSD_raw', {'function': 'flat'})
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# ../..//dataset/extdia_v1\slider6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9946345158439591
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9794138997601313
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9947506316230804
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9922849247429477
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9999763287463703
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9987375331397551
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9944299962125994
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8307031940411564
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9864343990657746
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.95510352228254
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9847592195149323
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7816142742919665
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9958299141522534
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9731410175482893
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9777502840550435
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6648150486049742
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9967748389097827
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9988752506235024
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.999132921940453
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7703920136352569
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9982078012383969
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 1.0
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9856956334340568
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9396386005382547
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9846979398981429
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8574746931390288
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9851270463292445
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5803506208911614
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9943212547322877
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.93625
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9843492794226211
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7555747789311803
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9991612209990789
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9724568213511703
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 1.0
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.999875854470403
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9999936064787681
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9801245210727969
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.999943888000449
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.995488064087906
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9819223937546598
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.651576526269401
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9990547875704565
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7925062654696967
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9981757152751879
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7692520478266613
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9986486360108109
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9305253949862263
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9924695943102433
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9825577289739426
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9911379517793513
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9927083333333333
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB04_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9941722623966942
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9520833333333334
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB06_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9950327729147379
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6207291666666667
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9776422176163623
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9683285078737377
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9781514646674998
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8187499999999999
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB04_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9814365960743803
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6804513888888888
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB06_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9826982156384143
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5073263888888888
# pipe saved to pickle

# %% [markdown]
# ## SVM

# %%
diagram = 'extdia_v1'
machines = ['slider',
            'pump',
            'fan',
            'valve',
            ]
SNRs = ['min6dB', '6dB'
        ]
IDs = ['00'
       , '02'
       , '04'
       , '06'
        ]
features = [#('MEL_denbssm', {'function':'frame', 'frames':3})
            #, ('MEL_denbssm', {'function':'frame', 'frames':5})
            #, ('MEL_denbssm', {'function':'frame', 'frames':7})
            #, ('MEL_denbssm', {'function':'flat'})
            #('PSD_denbssm', {'function':'flat'})
            #, ('MEL_bssm', {'function':'frame', 'frames':3})
            #, ('MEL_bssm', {'function':'frame', 'frames':5})
            #, ('MEL_bssm', {'function':'frame', 'frames':7})
            #, ('MEL_bssm', {'function':'flat'})
            #, ('PSD_bssm', {'function':'flat'})
            #, ('MEL_raw', {'function':'frame', 'frames':3})
            #, ('MEL_raw', {'function':'frame', 'frames':5})
            #, ('MEL_raw', {'function':'frame', 'frames':7})
            #, ('MEL_raw', {'function':'flat'})
             ('PSD_raw', {'function':'flat'})
            #, ('MEL_den', {'function':'frame', 'frames':3})
            #, ('MEL_den', {'function':'frame', 'frames':5})
            #, ('MEL_den', {'function':'frame', 'frames':7})
            #, ('MEL_den', {'function':'flat'})
            #, ('PSD_den', {'function':'flat'})
            #, ('ICA_demix', {'function':'flat'})
            #, ('ICA_demix', {'function':'maxrange'})
            ]

tasks = []
for machine in machines:
    for SNR in SNRs:
        for ID in IDs:
            for feature in features:
                print(machine,SNR,ID,feature)
                if machine == 'valve':
                    diagram_patch = 'extdia_v1_sporafic'
                else:
                    diagram_patch = diagram
                path = glob.glob(BASE_FOLDER \
                    + '/dataset/{}/{}{}{}_EDiaV1*aug0'.format(diagram_patch, machine, SNR, ID) 
                    + "*pandaDisc*.pkl", recursive=True)[0]
                d = {
                'path_descr': path,
                'feat':feature[1], 
                'feat_col':feature[0], 
                'SNR':SNR, 
                'machine':machine, 
                'ID':ID,
                'BASE_FOLDER':BASE_FOLDER}
                tasks.append(d)


preprocessing = [
    #(PCA, {'n_components':64}),
    (StandardScaler, {})
]

modeling = (uni_svm, {'C': 0.1, 'degree':3,'kernel':'rbf'})

# modeling = (uni_EllipticEnvelope, {})

pipes = [Pipe(preprocessing, modeling, pseudo_sup=True) for i in range(len(tasks))]

tasks_failed = []
for pipe, task in tqdm(zip(pipes, tasks), total=len(tasks)):
    try:
        pipe.run_pipe(task)
    except:
        tasks_failed.append(task)
        print('Task failed')
# Out:
# slider min6dB 00 ('PSD_raw', {'function': 'flat'})
# slider min6dB 02 ('PSD_raw', {'function': 'flat'})
# slider min6dB 04 ('PSD_raw', {'function': 'flat'})
# slider min6dB 06 ('PSD_raw', {'function': 'flat'})
# slider 6dB 00 ('PSD_raw', {'function': 'flat'})
# slider 6dB 02 ('PSD_raw', {'function': 'flat'})
# slider 6dB 04 ('PSD_raw', {'function': 'flat'})
# slider 6dB 06 ('PSD_raw', {'function': 'flat'})
# pump min6dB 00 ('PSD_raw', {'function': 'flat'})
# pump min6dB 02 ('PSD_raw', {'function': 'flat'})
# pump min6dB 04 ('PSD_raw', {'function': 'flat'})
# pump min6dB 06 ('PSD_raw', {'function': 'flat'})
# pump 6dB 00 ('PSD_raw', {'function': 'flat'})
# pump 6dB 02 ('PSD_raw', {'function': 'flat'})
# pump 6dB 04 ('PSD_raw', {'function': 'flat'})
# pump 6dB 06 ('PSD_raw', {'function': 'flat'})
# fan min6dB 00 ('PSD_raw', {'function': 'flat'})
# fan min6dB 02 ('PSD_raw', {'function': 'flat'})
# fan min6dB 04 ('PSD_raw', {'function': 'flat'})
# fan min6dB 06 ('PSD_raw', {'function': 'flat'})
# fan 6dB 00 ('PSD_raw', {'function': 'flat'})
# fan 6dB 02 ('PSD_raw', {'function': 'flat'})
# fan 6dB 04 ('PSD_raw', {'function': 'flat'})
# fan 6dB 06 ('PSD_raw', {'function': 'flat'})
# valve min6dB 00 ('PSD_raw', {'function': 'flat'})
# valve min6dB 02 ('PSD_raw', {'function': 'flat'})
# valve min6dB 04 ('PSD_raw', {'function': 'flat'})
# valve min6dB 06 ('PSD_raw', {'function': 'flat'})
# valve 6dB 00 ('PSD_raw', {'function': 'flat'})
# valve 6dB 02 ('PSD_raw', {'function': 'flat'})
# valve 6dB 04 ('PSD_raw', {'function': 'flat'})
# valve 6dB 06 ('PSD_raw', {'function': 'flat'})
# HBox(children=(FloatProgress(value=0.0, max=32.0), HTML(value='')))
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9791969132685268
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9810472162605731
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9761456107456191
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9147975143430261
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9853790556747886
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9157303370786516
# pipe saved to pickle
# ../..//dataset/extdia_v1\slidermin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9616159575811134
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9275344022219417
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9848336305390734
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9985915604090393
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9917144767542444
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9966193942964553
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9980195051129908
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9960863527332408
# pipe saved to pickle
# ../..//dataset/extdia_v1\slider6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9710970837015528
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9731725792197955
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9798501280262739
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7658565211012764
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9758857208634246
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6096096096096096
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9905271464994867
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9016
# pipe saved to pickle
# ../..//dataset/extdia_v1\pumpmin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9834700512176221
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6857939254133025
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9890711079542784
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9922245586581251
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9932773298500067
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.764791818845873
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9930629904747187
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9991
# pipe saved to pickle
# ../..//dataset/extdia_v1\pump6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9806604184530169
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.931276432141484
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.967761830621464
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4339235371176403
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9896652140975654
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.49216331344418485
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9809036176674303
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.2707012154842119
# pipe saved to pickle
# ../..//dataset/extdia_v1\fanmin6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.985749890114001
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6386921524543243
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.991856168589097
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.3680553459423238
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.998484880076173
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6530753175409874
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB04_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9955756833075816
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.41075439291848326
# pipe saved to pickle
# ../..//dataset/extdia_v1\fan6dB06_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9962451720300386
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9214938498016436
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9671258206379933
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.96568038980298
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9631287889305382
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9575
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB04_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9677995867768595
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9004861111111111
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valvemin6dB06_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9667727095783183
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6193750000000001
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.971014645231883
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9814278652637526
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9646009764449998
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9752083333333332
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB04_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9798476239669421
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9435416666666667
# pipe saved to pickle
# ../..//dataset/extdia_v1_sporafic\valve6dB06_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9834820301321439
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6558333333333334
# pipe saved to pickle

# %%
tasks_failed
# Out:
# []
