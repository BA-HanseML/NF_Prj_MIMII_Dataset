# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Structure-cheat-sheet" data-toc-modified-id="Structure-cheat-sheet-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Structure cheat sheet</a></span></li><li><span><a href="#Data-structure" data-toc-modified-id="Data-structure-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data structure</a></span></li><li><span><a href="#get-features" data-toc-modified-id="get-features-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>get features</a></span></li><li><span><a href="#Exploration-of-the-Features" data-toc-modified-id="Exploration-of-the-Features-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploration of the Features</a></span></li><li><span><a href="#Exploring-spectral-features" data-toc-modified-id="Exploring-spectral-features-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exploring spectral features</a></span></li></ul></div>

# %% [markdown]
# # Basics
#
# ## Structure cheat sheet
#
# 1. func: train data lead (following order)
#     1. read the descriptive dataframe from the feature-pipeline
#     2. extract feature from the feature-objects which are labeled train-dataset from dataframe
#     3. create numpy feature array for the processing pipeline
# 2. preprocessing
#     1. Transformation (any combination of the following)
#         + log-transform
#         + PCA
#         + others
#     2. Scaling (one of the following)
#         + StandardScaler
#         + MinMaxScaler
# 3. Unsupervised Clustering
#     1. Estimate initial hyperparameter
#     2. Create grid over various hyperparameters
#     3. Train all and choose the best according to metric
#
#
# in all steps the cluster-recorder object (possibly dataframe-row) will record all the meta-information like hyper-parameters

# %% [markdown]
# ## Data structure
#
# There are multiple degrees of freedom in the data:
#
# 1. Signal to noise ratio (SNR)
# 2. Machine type
#     1. pump
#     2. fan
#     3. valve (solenoid)
#     4. slider
# 3. Machine ID
#     1. four different machine IDs
#
# The pipeline will be applied to fixed SNR, fixed machine type and fixed ID

# %% [markdown]
# ## get features
#
# Get the descriptive dataframe for the features.
#
# The descriptive dataframe contains all IDs of the pump. We will focus on ID '00' for now since the modeling phase is seperated per SNR, per machine, per ID anyway.

# %% [markdown]
# class:
# + uni\_\<model\>
# attributes:
# + default threshold
# + roc_auc
# methods:
# + fit
# + predict
# + predict_score
# + eval_roc_auc

# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from tqdm.auto import tqdm
import glob
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load tensorflow models
# Load detection_pipe

# %% [markdown]
# ## RFC

# %%
diagram = 'extdia_v1'
machines = ['slider',
            'pump',
            'fan',
            'valve',
            ]
SNRs = ['min6dB'#, 'min6dB'
        ]
IDs = ['00'
       , '02'
       ,# '04'
       #, '06'
        ]
features = [#('MEL_denbssm', {'function':'frame', 'frames':3})
            #, ('MEL_denbssm', {'function':'frame', 'frames':5})
            #, ('MEL_denbssm', {'function':'frame', 'frames':7})
            #, ('MEL_denbssm', {'function':'flat'})
            ('PSD_denbssm', {'function':'flat'})
            #, ('MEL_bssm', {'function':'frame', 'frames':3})
            #, ('MEL_bssm', {'function':'frame', 'frames':5})
            #, ('MEL_bssm', {'function':'frame', 'frames':7})
            #, ('MEL_bssm', {'function':'flat'})
            , ('PSD_bssm', {'function':'flat'})
            #, ('MEL_raw', {'function':'frame', 'frames':3})
            #, ('MEL_raw', {'function':'frame', 'frames':5})
            #, ('MEL_raw', {'function':'frame', 'frames':7})
            #, ('MEL_raw', {'function':'flat'})
            , ('PSD_raw', {'function':'flat'})
            #, ('MEL_den', {'function':'frame', 'frames':3})
            #, ('MEL_den', {'function':'frame', 'frames':5})
            #, ('MEL_den', {'function':'frame', 'frames':7})
            #, ('MEL_den', {'function':'flat'})
            , ('PSD_den', {'function':'flat'})
            , ('ICA_demix', {'function':'flat'})
            , ('ICA_demix', {'function':'maxrange'})
            ]

tasks = []
for machine in machines:
    for SNR in SNRs:
        for ID in IDs:
            for feature in features:
                print(machine,SNR,ID,feature)
                if machine == 'valve':
                    diagram_patch = 'extdia_v1_sporafic'
                else:
                    diagram_patch = diagram
                path = glob.glob(BASE_FOLDER \
                    + '/dataset/{}/{}{}{}_EDiaV1*aug0'.format(diagram_patch, machine, SNR, ID) 
                    + "*pandaDisc*.pkl", recursive=True)[0]
                d = {
                'path_descr': path,
                'feat':feature[1], 
                'feat_col':feature[0], 
                'SNR':SNR, 
                'machine':machine, 
                'ID':ID,
                'BASE_FOLDER':BASE_FOLDER}
                tasks.append(d)


preprocessing = [
    #(PCA, {'n_components':64}),
    (StandardScaler, {})
]

modeling = (uni_RandomForestClassifier, {'max_depth': 2})

# modeling = (uni_EllipticEnvelope, {})

pipes = [Pipe(preprocessing, modeling, pseudo_sup=True) for i in range(len(tasks))]

tasks_failed = []
for pipe, task in tqdm(zip(pipes, tasks), total=len(tasks)):
    try:
        pipe.run_pipe(task)
    except:
        tasks_failed.append(task)
        print('Task failed')
# Out:
# slider min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# slider min6dB 00 ('PSD_bssm', {'function': 'flat'})
# slider min6dB 00 ('PSD_raw', {'function': 'flat'})
# slider min6dB 00 ('PSD_den', {'function': 'flat'})
# slider min6dB 00 ('ICA_demix', {'function': 'flat'})
# slider min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# slider min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# slider min6dB 02 ('PSD_bssm', {'function': 'flat'})
# slider min6dB 02 ('PSD_raw', {'function': 'flat'})
# slider min6dB 02 ('PSD_den', {'function': 'flat'})
# slider min6dB 02 ('ICA_demix', {'function': 'flat'})
# slider min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# pump min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# pump min6dB 00 ('PSD_bssm', {'function': 'flat'})
# pump min6dB 00 ('PSD_raw', {'function': 'flat'})
# pump min6dB 00 ('PSD_den', {'function': 'flat'})
# pump min6dB 00 ('ICA_demix', {'function': 'flat'})
# pump min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# pump min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# pump min6dB 02 ('PSD_bssm', {'function': 'flat'})
# pump min6dB 02 ('PSD_raw', {'function': 'flat'})
# pump min6dB 02 ('PSD_den', {'function': 'flat'})
# pump min6dB 02 ('ICA_demix', {'function': 'flat'})
# pump min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# fan min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# fan min6dB 00 ('PSD_bssm', {'function': 'flat'})
# fan min6dB 00 ('PSD_raw', {'function': 'flat'})
# fan min6dB 00 ('PSD_den', {'function': 'flat'})
# fan min6dB 00 ('ICA_demix', {'function': 'flat'})
# fan min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# fan min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# fan min6dB 02 ('PSD_bssm', {'function': 'flat'})
# fan min6dB 02 ('PSD_raw', {'function': 'flat'})
# fan min6dB 02 ('PSD_den', {'function': 'flat'})
# fan min6dB 02 ('ICA_demix', {'function': 'flat'})
# fan min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# valve min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# valve min6dB 00 ('PSD_bssm', {'function': 'flat'})
# valve min6dB 00 ('PSD_raw', {'function': 'flat'})
# valve min6dB 00 ('PSD_den', {'function': 'flat'})
# valve min6dB 00 ('ICA_demix', {'function': 'flat'})
# valve min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# valve min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# valve min6dB 02 ('PSD_bssm', {'function': 'flat'})
# valve min6dB 02 ('PSD_raw', {'function': 'flat'})
# valve min6dB 02 ('PSD_den', {'function': 'flat'})
# valve min6dB 02 ('ICA_demix', {'function': 'flat'})
# valve min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# HBox(children=(FloatProgress(value=0.0, max=48.0), HTML(value='')))
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9394952894205277
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.47448633379623784
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9603457186592601
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.757046143163742
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9830691358414342
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9248911122333039
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9674184919833356
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9180501199343518
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8578432726297185
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6031632685267011
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.720014439464714
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9250134137103901
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9357490091193748
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.48118223007757155
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9587173336699911
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6176198291461515
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9866887676297262
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7824278640463465
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9720745447715948
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8118994515282862
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.884133597048633
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.613334455526098
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7319175001285846
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7117227061678519
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9691944750654231
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5537190082644627
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.982669794258354
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6370727174922979
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9847597040156075
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8369357914812461
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9633839485800295
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7765171891046017
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9152542600457324
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7630690987334343
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7796894070510454
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8175216391999609
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9678061298540106
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5984498011525039
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9858633745226693
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.739388036685334
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9854761297038671
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6288044801558315
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9574800184175888
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6822498173849525
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8868644555550552
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5710981251521792
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7660415696990627
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7831344858371885
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9547730910924959
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5191308127426064
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9656100609622384
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5159041104987051
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9812700100872769
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6543715929465317
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9509821389412745
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5921013709711498
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.850701449497829
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5229823301076371
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7295485943598965
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5328918375601422
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.991384203368941
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7168977583972812
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9937530261856277
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.842661059426913
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9994439926885038
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8240392299873528
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9899455344504448
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7658188561541268
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9264147490206162
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5582436511200255
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8679401550797059
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6211272414087414
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9703077655500376
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8637101899583363
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9751678099486576
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9291010521855801
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.978973124105715
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.968434432596568
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9629220236091238
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9292422851493539
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9430327308307381
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.870807146387967
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8204374368740005
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9782854318197868
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9787386042852515
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8764583333333332
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed

# %% [markdown]
# ## SVM

# %%
diagram = 'extdia_v1'
machines = ['slider',
            'pump',
            'fan',
            'valve',
            ]
SNRs = ['min6dB'#, 'min6dB'
        ]
IDs = ['00'
       , '02'
       ,# '04'
       #, '06'
        ]
features = [#('MEL_denbssm', {'function':'frame', 'frames':3})
            #, ('MEL_denbssm', {'function':'frame', 'frames':5})
            #, ('MEL_denbssm', {'function':'frame', 'frames':7})
            #, ('MEL_denbssm', {'function':'flat'})
            ('PSD_denbssm', {'function':'flat'})
            #, ('MEL_bssm', {'function':'frame', 'frames':3})
            #, ('MEL_bssm', {'function':'frame', 'frames':5})
            #, ('MEL_bssm', {'function':'frame', 'frames':7})
            #, ('MEL_bssm', {'function':'flat'})
            , ('PSD_bssm', {'function':'flat'})
            #, ('MEL_raw', {'function':'frame', 'frames':3})
            #, ('MEL_raw', {'function':'frame', 'frames':5})
            #, ('MEL_raw', {'function':'frame', 'frames':7})
            #, ('MEL_raw', {'function':'flat'})
            , ('PSD_raw', {'function':'flat'})
            #, ('MEL_den', {'function':'frame', 'frames':3})
            #, ('MEL_den', {'function':'frame', 'frames':5})
            #, ('MEL_den', {'function':'frame', 'frames':7})
            #, ('MEL_den', {'function':'flat'})
            , ('PSD_den', {'function':'flat'})
            , ('ICA_demix', {'function':'flat'})
            , ('ICA_demix', {'function':'maxrange'})
            ]

tasks = []
for machine in machines:
    for SNR in SNRs:
        for ID in IDs:
            for feature in features:
                print(machine,SNR,ID,feature)
                if machine == 'valve':
                    diagram_patch = 'extdia_v1_sporafic'
                else:
                    diagram_patch = diagram
                path = glob.glob(BASE_FOLDER \
                    + '/dataset/{}/{}{}{}_EDiaV1*aug0'.format(diagram_patch, machine, SNR, ID) 
                    + "*pandaDisc*.pkl", recursive=True)[0]
                d = {
                'path_descr': path,
                'feat':feature[1], 
                'feat_col':feature[0], 
                'SNR':SNR, 
                'machine':machine, 
                'ID':ID,
                'BASE_FOLDER':BASE_FOLDER}
                tasks.append(d)


preprocessing = [
    #(PCA, {'n_components':64}),
    (StandardScaler, {})
]

modeling = (uni_svm, {'C': 0.1, 'degree':3,'kernel':'rbf'})

# modeling = (uni_EllipticEnvelope, {})

pipes = [Pipe(preprocessing, modeling, pseudo_sup=True) for i in range(len(tasks))]

tasks_failed = []
for pipe, task in tqdm(zip(pipes, tasks), total=len(tasks)):
    try:
        pipe.run_pipe(task)
    except:
        tasks_failed.append(task)
        print('Task failed')
# Out:
# slider min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# slider min6dB 00 ('PSD_bssm', {'function': 'flat'})
# slider min6dB 00 ('PSD_raw', {'function': 'flat'})
# slider min6dB 00 ('PSD_den', {'function': 'flat'})
# slider min6dB 00 ('ICA_demix', {'function': 'flat'})
# slider min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# slider min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# slider min6dB 02 ('PSD_bssm', {'function': 'flat'})
# slider min6dB 02 ('PSD_raw', {'function': 'flat'})
# slider min6dB 02 ('PSD_den', {'function': 'flat'})
# slider min6dB 02 ('ICA_demix', {'function': 'flat'})
# slider min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# pump min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# pump min6dB 00 ('PSD_bssm', {'function': 'flat'})
# pump min6dB 00 ('PSD_raw', {'function': 'flat'})
# pump min6dB 00 ('PSD_den', {'function': 'flat'})
# pump min6dB 00 ('ICA_demix', {'function': 'flat'})
# pump min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# pump min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# pump min6dB 02 ('PSD_bssm', {'function': 'flat'})
# pump min6dB 02 ('PSD_raw', {'function': 'flat'})
# pump min6dB 02 ('PSD_den', {'function': 'flat'})
# pump min6dB 02 ('ICA_demix', {'function': 'flat'})
# pump min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# fan min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# fan min6dB 00 ('PSD_bssm', {'function': 'flat'})
# fan min6dB 00 ('PSD_raw', {'function': 'flat'})
# fan min6dB 00 ('PSD_den', {'function': 'flat'})
# fan min6dB 00 ('ICA_demix', {'function': 'flat'})
# fan min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# fan min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# fan min6dB 02 ('PSD_bssm', {'function': 'flat'})
# fan min6dB 02 ('PSD_raw', {'function': 'flat'})
# fan min6dB 02 ('PSD_den', {'function': 'flat'})
# fan min6dB 02 ('ICA_demix', {'function': 'flat'})
# fan min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# valve min6dB 00 ('PSD_denbssm', {'function': 'flat'})
# valve min6dB 00 ('PSD_bssm', {'function': 'flat'})
# valve min6dB 00 ('PSD_raw', {'function': 'flat'})
# valve min6dB 00 ('PSD_den', {'function': 'flat'})
# valve min6dB 00 ('ICA_demix', {'function': 'flat'})
# valve min6dB 00 ('ICA_demix', {'function': 'maxrange'})
# valve min6dB 02 ('PSD_denbssm', {'function': 'flat'})
# valve min6dB 02 ('PSD_bssm', {'function': 'flat'})
# valve min6dB 02 ('PSD_raw', {'function': 'flat'})
# valve min6dB 02 ('PSD_den', {'function': 'flat'})
# valve min6dB 02 ('ICA_demix', {'function': 'flat'})
# valve min6dB 02 ('ICA_demix', {'function': 'maxrange'})
# HBox(children=(FloatProgress(value=0.0, max=48.0), HTML(value='')))
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9002789262719353
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7796127382906199
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9595221562933973
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8036074990531499
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9798478727433405
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9849174662290116
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9406620849640198
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9657989837141775
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9089958654210326
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6203525438707234
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7126309809367504
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9201174094180028
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9127791259676965
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6745079886097434
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9587383747843286
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8493596487536647
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9779808634961604
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9150149391911795
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9071603691390755
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8841055422295165
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8866538549659367
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7171793684860217
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\slidermin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7104368602916766
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6932696488939389
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9308543991492665
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5649175998826349
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9768384559507713
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5527409653283779
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9811189778307098
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7766638955450144
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9430924219455966
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.31260697344613425
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9166855763330644
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4452051445058438
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7854959054418216
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8316788106997898
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9416918156839782
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6111111111111112
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9714552397539651
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6397208018829641
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9764212322768244
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6104212320428537
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8842081688012051
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5691096501907313
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8920594167429896
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6324161999837675
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\pumpmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7665695739431156
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7837837837837838
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8667602298144819
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5486057869350253
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9489016380860488
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5040929918079795
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9665584842770055
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4365978665732965
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9209738607955791
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.429954300961672
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8770147142669181
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.49108657462465816
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7228164334897593
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.4995653460026924
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9700057222419141
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6361566095855867
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9934669140899202
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5911810119412482
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9893385598020614
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.48098245668484885
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9465225217711614
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5387915984512845
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9104712393634642
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.5936328861507902
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1\fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.7717427817509133
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.46276022066867883
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_denbssm
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_denbssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9674355325730157
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9545229856648543
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_bssm
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_bssm
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9732122190893023
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9664571711037355
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9685139350643885
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9632088129369395
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_den
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_den
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9472069375473444
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9434361980086152
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9491875157815
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.961867099781089
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB00_EDiaV1HPaug0TsSl_pandaDisc.pkl ICA_demix
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.8507372590691019
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9815690982275264
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# ##2
# ##10 ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl PSD_raw
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9677680596047943
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9393055555555555
# pipe saved to pickle
# #######
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed
# ###sff####
# ../..//dataset/extdia_v1_sporafic\valvemin6dB02_EDiaV1HPaug0TsSl_pandaDisc.pkl --> Done
# lll
# ...loading data
# ##2
# Task failed

# %%
tasks_failed
# Out:
# []
