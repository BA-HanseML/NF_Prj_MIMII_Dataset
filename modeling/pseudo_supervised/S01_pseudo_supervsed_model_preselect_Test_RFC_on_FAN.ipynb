# %% [markdown]
# # Model Preselect test logeristic regression

# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from sklearn.preprocessing import PolynomialFeatures

# %run -i miniutil_singel_pipe_eval_helper.py

df_summery = pd.DataFrame()
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load tensorflow models
# Load detection_pipe

# %% [markdown]
# # Feature list
#
# * PSD_raw
# * PSD_den
# * PSD_bssm
# * PSD_denbssm
# * ICA_demix
# * MEL_raw
# * MEL_den
# * MEL_bssm
# * MEL_denbssm

# %% [markdown]
# # Low noise ID00

# %%
## Meta
machines = ['fan']
SNRs = ['6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_bssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9963995548440858
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.8897125850442804
# pipe saved to pickle
# RFCn_fan006dBPSD_bssm

# %% [markdown]
# ## PSD_den

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_den'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9954196087890882
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.91804357406323
# pipe saved to pickle
# RFCn_fan006dBPSD_den

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9976810227621595
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.9564380104920647
# pipe saved to pickle
# RFCn_fan006dBPSD_raw

# %% [markdown]
# # High noise ID00

# %%
## Meta
machines = ['fan']
SNRs = ['min6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9796184926099732
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.659720251857844
# pipe saved to pickle
# RFCn_fan00min6dBPSD_raw

# %% [markdown]
# ## PSD_den

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9613462677075566
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.514014572982632
# pipe saved to pickle
# RFCn_fan00min6dBPSD_bssm

# %% [markdown]
# # High noise ID02

# %%
## Meta
machines = ['fan']
SNRs = ['min6dB']
IDs = ['02']
feat_discfile = '/dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9991578805927965
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.841865752127932
# pipe saved to pickle
# RFCn_fan02min6dBPSD_raw

# %% [markdown]
# ## PSD_den

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

#modeling = (uni_LogisticRegression, {'C': 0.5, 'max_iter': 600})
modeling = (uni_RandomForestClassifier, {'max_depth': 2})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB02_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9956237591190991
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7920601174727075
# pipe saved to pickle
# RFCn_fan02min6dBPSD_bssm

# %% [markdown]
# # Summery

# %%
df_summery.to_pickle('S01_summerys/S01_RFC_fan')
