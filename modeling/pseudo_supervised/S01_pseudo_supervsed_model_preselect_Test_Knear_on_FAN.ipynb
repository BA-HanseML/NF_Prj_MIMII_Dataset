# %%
#===============================================
# Basic Imports
BASE_FOLDER = '../../'
# %run -i ..\..\utility\feature_extractor\JupyterLoad_feature_extractor.py
# %run -i ..\..\utility\modeling\JupyterLoad_modeling.py
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, FastICA
from sklearn.preprocessing import PolynomialFeatures

# %run -i miniutil_singel_pipe_eval_helper.py

df_summery = pd.DataFrame()
# Out:
# load feature_extractor_mother
# load feature_extractor_mel_spectra
# load feature_extractor_psd
# load feature_extractor_ICA2
# load feature_extractore_pre_nnFilterDenoise
# load extractor_diagram_mother
# load Simple_FIR_HP
# load TimeSliceAppendActivation
# load load_data
# Load split_data
# Load anomaly_detection_models
# Load pseudo_supervised_models
# Load tensorflow models
# Load detection_pipe

# %% [markdown]
# # Feature list
#
# * PSD_raw
# * PSD_den
# * PSD_bssm
# * PSD_denbssm
# * ICA_demix
# * MEL_raw
# * MEL_den
# * MEL_bssm
# * MEL_denbssm

# %% [markdown]
# # Low noise ID00

# %%
## Meta
machines = ['fan']
SNRs = ['6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    #(MinMaxScaler, {}),
    #(PCA, {'n_components':120})
    #(PolynomialFeatures, {'degree': 2})
]

modeling = (uni_KNeighborsClassifier, {'n_neighbors': 100, 'algorithm':'auto'})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + '' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9977399565808517
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6554310620649687
# pipe saved to pickle
# KNC_fan006dBPSD_raw

# %% [markdown]
# ## PSD_den

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_den'],
                        feat = {'function':'flat'})

preprocessing = [
    #(MinMaxScaler, {}),
    #(PCA, {'n_components':120})
    #(PolynomialFeatures, {'degree': 2})
]

modeling = (uni_KNeighborsClassifier, {'n_neighbors': 100, 'algorithm':'auto'})

pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + '' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.973985515986141
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.7032460201993371
# pipe saved to pickle
# KNC_fan006dBPSD_den

# %% [markdown]
# ## PSD_bssm

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_bssm'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

modeling = (uni_KNeighborsClassifier, {'n_neighbors': 100, 'algorithm':'auto'})


pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fan6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9945164137537829
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.6524428158334792
# pipe saved to pickle
# KNCn_fan006dBPSD_bssm

# %% [markdown]
# # High noise ID00

# %%
## Meta
machines = ['fan']
SNRs = ['min6dB']
IDs = ['00']
feat_discfile = '/dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl'

# %% [markdown]
# ## PSD_raw

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_raw'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

modeling = (uni_KNeighborsClassifier, {'n_neighbors': 100, 'algorithm':'auto'})


pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.9792059558791281
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.48957132249515545
# pipe saved to pickle
# KNCn_fan00min6dBPSD_raw

# %% [markdown]
# # PSD_den

# %%
df, tasks, npart = Make_TTsplit_and_task(feat_discfile,machines, SNRs,IDs,
                        features = [ 'PSD_den'],
                        feat = {'function':'flat'})

preprocessing = [
    (StandardScaler, {}),
    #(PolynomialFeatures, {'degree': 2})
]

modeling = (uni_KNeighborsClassifier, {'n_neighbors': 100, 'algorithm':'auto'})


pipe = Pipe(preprocessing, modeling, True)
pipe.run_pipe(tasks[0])

name_of_test = pipe.model.name + 'n' +'_' + npart

pipetask_to_metrics(pipe,tasks[0],df_summery,name_of_test,0.5)
print(name_of_test)
# Out:
# ../..//dataset/extdia_v1/fanmin6dB00_EDiaV1HPaug0_pandaDisc.pkl --> Done
# ...loading data
# data loading completed
#
# ...preprocessing data
# data preprocessing finished
#
# ...fitting the model
# 0.942531303451603
# model fitted successfully
#
# ...evaluating model
# evaluation successfull, roc_auc: 0.48585865293482
# pipe saved to pickle
# KNCn_fan00min6dBPSD_den

# %%
df_summery.to_pickle('S01_summerys/S01_KCA_valve')
