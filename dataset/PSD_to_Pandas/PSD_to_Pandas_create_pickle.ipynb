# %%
# load utilty
# %run ../../utility/PSD_to_Pandas.py
# %run ../../utility/PSD_fileplot.py

# %%
pwd
# Out:
# 'A:\\Dev\\NF_Prj_MIMII_Dataset\\dataset\\PSD_to_Pandas'

# %% [markdown]
# # check basic setting and freq band

# %%
for n in ['00','02','04','06']:
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\normal\00000001.wav')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\normal\00000020.wav')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\abnormal\00000001.wav',color='red')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\abnormal\00000020.wav',color='red')
    plt.title(n)
    plt.show()

# %% [markdown]
# # Create Pandas DF

# %%
# create frame
import time  
t = time.time()
FileFindDict={'SNR': '6dB','machine': 'valve','ID': ['00','02','04','06']}
PSDname = 'full_spectrum_128'
pump = PSD_to_Pandas(PSD_window='hamming',
                     PSD_nperseg = 128,
                     PSD_nfft=512,
                     PSD_scaling='spectrum',
                     base_folder='../../', 
                     FileFindDict=FileFindDict, 
                     FileCountlimit=None, # !test with lesser this can take long time !
                     ChannelNr=0,
                     freq_band = [200,8000])

elapsed = time.time() - t
print(elapsed)
# save
FileName = FileFindDict['machine'] + '_' + \
           FileFindDict['SNR'] + '_' + \
           ''.join(FileFindDict['ID']) + '_' + PSDname + '.pkl'

pump.to_pickle(FileName)
# Out:
# A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\valve\id_00\normal\00000000.wav
# b
# [   0.     31.25   62.5    93.75  125.    156.25  187.5   218.75  250.
#   281.25  312.5   343.75  375.    406.25  437.5   468.75  500.    531.25
#   562.5   593.75  625.    656.25  687.5   718.75  750.    781.25  812.5
#   843.75  875.    906.25  937.5   968.75 1000.   1031.25 1062.5  1093.75
#  1125.   1156.25 1187.5  1218.75 1250.   1281.25 1312.5  1343.75 1375.
#  1406.25 1437.5  1468.75 1500.   1531.25 1562.5  1593.75 1625.   1656.25
#  1687.5  1718.75 1750.   1781.25 1812.5  1843.75 1875.   1906.25 1937.5
#  1968.75 2000.   2031.25 2062.5  2093.75 2125.   2156.25 2187.5  2218.75
#  2250.   2281.25 2312.5  2343.75 2375.   2406.25 2437.5  2468.75 2500.
#  2531.25 2562.5  2593.75 2625.   2656.25 2687.5  2718.75 2750.   2781.25
#  2812.5  2843.75 2875.   2906.25 2937.5  2968.75 3000.   3031.25 3062.5
#  3093.75 3125.   3156.25 3187.5  3218.75 3250.   3281.25 3312.5  3343.75
# ...

# %%
pump.head()
# Out:
#                                              path abnormal  ID      file  \
# 0     \dataset\6dB\pump\id_00\normal\00000000.wav        0  00  00000000
# 1     \dataset\6dB\pump\id_00\normal\00000001.wav        0  00  00000001
# 2   \dataset\6dB\pump\id_00\abnormal\00000000.wav        1  00  00000000
# 3   \dataset\6dB\pump\id_00\abnormal\00000001.wav        1  00  00000001
# 4     \dataset\6dB\pump\id_02\normal\00000000.wav        0  02  00000000
# 5     \dataset\6dB\pump\id_02\normal\00000001.wav        0  02  00000001
# 6   \dataset\6dB\pump\id_02\abnormal\00000000.wav        1  02  00000000
# 7   \dataset\6dB\pump\id_02\abnormal\00000001.wav        1  02  00000001
# 8     \dataset\6dB\pump\id_04\normal\00000000.wav        0  04  00000000
# 9     \dataset\6dB\pump\id_04\normal\00000001.wav        0  04  00000001
# 10  \dataset\6dB\pump\id_04\abnormal\00000000.wav        1  04  00000000
# 11  \dataset\6dB\pump\id_04\abnormal\00000001.wav        1  04  00000001
# ...

# %%
pd.read_pickle('pump_6dB_00020406_full_spectrum_128.pkl')
# Out:
#                                              path abnormal  ID      file  \
# 0     \dataset\6dB\pump\id_00\normal\00000000.wav        0  00  00000000
# 1     \dataset\6dB\pump\id_00\normal\00000001.wav        0  00  00000001
# 2   \dataset\6dB\pump\id_00\abnormal\00000000.wav        1  00  00000000
# 3   \dataset\6dB\pump\id_00\abnormal\00000001.wav        1  00  00000001
# 4     \dataset\6dB\pump\id_02\normal\00000000.wav        0  02  00000000
# 5     \dataset\6dB\pump\id_02\normal\00000001.wav        0  02  00000001
# 6   \dataset\6dB\pump\id_02\abnormal\00000000.wav        1  02  00000000
# 7   \dataset\6dB\pump\id_02\abnormal\00000001.wav        1  02  00000001
# 8     \dataset\6dB\pump\id_04\normal\00000000.wav        0  04  00000000
# 9     \dataset\6dB\pump\id_04\normal\00000001.wav        0  04  00000001
# 10  \dataset\6dB\pump\id_04\abnormal\00000000.wav        1  04  00000000
# 11  \dataset\6dB\pump\id_04\abnormal\00000001.wav        1  04  00000001
# ...

# %%
import time
t = time.time()

elapsed = time.time() - t
print(elapsed)
# Out:
# 0.0

# %% [markdown]
# # PSD check

# %% [markdown]
# ## FAN

# %%
for n in ['00','02','04','06']:
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\fan\id_'+ n + r'\normal\00000001.wav')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\fan\id_'+ n + r'\normal\00000020.wav')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\fan\id_'+ n + r'\abnormal\00000001.wav',color='red')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\fan\id_'+ n + r'\abnormal\00000020.wav',color='red')
    plt.title(n)
    plt.show()

# %% [markdown]
# ## slider

# %%
for n in ['00','02','04','06']:
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\normal\00000001.wav')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\normal\00000020.wav')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\abnormal\00000001.wav',color='red')
    PSD_fileplot(r'A:\Dev\NF_Prj_MIMII_Dataset\dataset\6dB\slider\id_'+ n + r'\abnormal\00000020.wav',color='red')
    plt.title(n)
    plt.show()
